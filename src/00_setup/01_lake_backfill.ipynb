# %%
# %skip
# CUIDADO: Apaga o banco e todas as tabelas dentro dele
spark.sql("DROP DATABASE IF EXISTS oftalmo_sus.01_bronze CASCADE")
spark.sql("DROP DATABASE IF EXISTS oftalmo_sus.02_silver CASCADE")
spark.sql("DROP DATABASE IF EXISTS oftalmo_sus.03_gold CASCADE")

# Recriando as pastas limpas
spark.sql("CREATE DATABASE oftalmo_sus.01_bronze")
spark.sql("CREATE DATABASE oftalmo_sus.02_silver")
spark.sql("CREATE DATABASE oftalmo_sus.03_gold")
