# %%
# %sql
CREATE CATALOG IF NOT EXISTS oftalmo_sus
COMMENT 'Catálogo principal para o projeto de ELT de dados do DATASUS'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS oftalmo_sus.00_landing
COMMENT 'Zona de landing - recepção de dados brutos de sistemas externos'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS oftalmo_sus.01_bronze
COMMENT 'Camada Bronze - dados brutos preservados de forma imutável'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS oftalmo_sus.02_silver
COMMENT 'Camada Silver - dados limpos, validados e enriquecidos'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS oftalmo_sus.03_gold
COMMENT 'Camada Gold - dados agregados e modelados para consumo final'

# %%
# %sql
SHOW SCHEMAS IN oftalmo_sus

# %%
# %sql
CREATE VOLUME oftalmo_sus.00_landing.raw_files
COMMENT 'Volume para armazenar arquivos brutos de ingestão incial (planilhas, csv, imagens, json, etc)';
